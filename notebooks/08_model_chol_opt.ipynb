# %%
# Cellule 1 : imports & config
RANDOM_STATE = 42

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    classification_report, roc_auc_score, RocCurveDisplay, ConfusionMatrixDisplay
)
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.inspection import permutation_importance

import lightgbm as lgb
import joblib
pd.set_option("display.max_columns", None)

print("OK imports.")
# Out:
# OK imports.

# %%
# Cellule 2 : chargement du CSV
df = pd.read_csv("nhanes_ready.csv")
print(df.shape)
df.head(3)
# Out:
# (6889, 38)
#        SEQN  RIDAGEYR  RIAGENDR  LBXTC  BMXHT  BMXBMI  BMXWT  BMXWAIST  \
# 0  130378.0      43.0         1  264.0  179.5    27.0   86.9      98.3
# 1  130379.0      66.0         1  214.0  174.2    33.5  101.8     114.7
# 2  130380.0      44.0         2  187.0  152.9    29.7   69.4      93.5
#
#    BMXARMC  PAD680  SLD012  DRKCAL  DRPROT   DRSUGR  DRFIBE  DRTFAT  \
# 0     35.7   360.0     9.5  1390.0  88.525   22.060    5.95  47.420
# 1     33.7   480.0     9.0  2484.5  82.620  113.495   24.15  73.190
# 2     36.3   240.0     8.0  1735.0  67.115  110.920   21.40  55.685
#
#         DRTALCO   DRCARB  DRWATER  smoker  diabetes  PAD680_log   DRTALCO_log  \
# 0  2.280000e+01  109.785   1020.0       1         0    5.888878  3.169686e+00
# 1  6.030000e+01  280.440    120.0       1         0    6.175867  4.115780e+00
# 2  5.397605e-79  245.325   1747.5       0         1    5.484797  5.397605e-79
#
#    DRWATER_log  DRSUGR_log  DRFIBE_log  DRCARB_log  DRPROT_log  DRTFAT_log  \
# 0     6.928538    3.138100    1.938742    4.707591    4.494518    3.879913
# 1     4.795791    4.740531    3.224858    5.639919    4.426283    4.306629
# 2     7.466514    4.717784    3.109061    5.506652    4.221197    4.037510
#
#    DRKCAL_log  BMXBMI_log  ethnicity_MexicanAmerican  \
# 0    7.237778    3.332205                      False
# 1    7.818229    3.540959                      False
# 2    7.459339    3.424263                      False
#
#    ethnicity_NonHispanicAsian  ethnicity_NonHispanicBlack  \
# 0                        True                       False
# 1                       False                       False
# 2                       False                       False
#
#    ethnicity_NonHispanicWhite  ethnicity_OtherHispanic  ethnicity_OtherRace  \
# 0                       False                    False                False
# 1                        True                    False                False
# 2                       False                     True                False
#
#    chol_high
# 0          1
# 1          0
# 2          0

# %%
# Cellule 3 : check NaN / doublons / cible
print("NaN totaux :", df.isna().sum().sum())
print("Doublons   :", df.duplicated().sum())

target = "chol_high"   # <-- NOUVELLE CIBLE
assert target in df.columns, "Colonne 'chol_high' absente du CSV."
print(df[target].value_counts(dropna=False))
print((df[target].value_counts(normalize=True)*100).round(2))
# Out:
# NaN totaux : 0
# Doublons   : 0
# chol_high
# 0    6272
# 1     617
# Name: count, dtype: int64
# chol_high
# 0    91.04
# 1     8.96
# Name: proportion, dtype: float64

# %%
# Cellule 4 — Définition des features

USE_ETHNICITY = True
target = "chol_high"

core = ["RIDAGEYR", "RIAGENDR", "smoker"]
morpho = ["BMXBMI_log", "BMXWAIST"]
lifestyle = ["PAD680_log", "SLD012"]
diet = ["DRKCAL_log", "DRPROT_log", "DRSUGR_log", "DRFIBE_log", "DRTFAT_log", 
        "DRCARB_log", "DRTALCO_log", "DRWATER_log" ]

ethn = [
    "ethnicity_MexicanAmerican", "ethnicity_OtherHispanic",
    "ethnicity_NonHispanicWhite", "ethnicity_NonHispanicBlack",
    "ethnicity_NonHispanicAsian", "ethnicity_OtherRace"
]

if USE_ETHNICITY:
    candidate_feats = core + morpho + lifestyle + diet  + ethn
else:
    candidate_feats = core + morpho + lifestyle + diet

features = [c for c in candidate_feats if c in df.columns]
missing = [c for c in candidate_feats if c not in df.columns]
if missing:
    print("Colonnes absentes (ignorées) :", missing)

X_full = df[features].copy()
y = df[target].astype(int)
print(f"X_full : {X_full.shape} | y pos rate : {y.mean():.3f}")
# Out:
# X_full : (6889, 21) | y pos rate : 0.090

# %%
# Cellule 5 — Corrélation

import seaborn as sns

df_corr = df.copy()

# Matrice de corrélation de Pearson
corr = df_corr.corr(method="pearson").round(3)
print("=== Matrice de corrélation (Pearson) ===")
display(corr)

# Corrélation spécifique avec le diabète
print("\nCorrélations avec 'chol_high' :")
print(corr["chol_high"].sort_values(ascending=False))
# Out:
# === Matrice de corrélation (Pearson) ===
#                              SEQN  RIDAGEYR  RIAGENDR  LBXTC  BMXHT  BMXBMI  \
# SEQN                        1.000     0.015     0.034  0.008 -0.012  -0.004
# RIDAGEYR                    0.015     1.000     0.007  0.222  0.233   0.277
# RIAGENDR                    0.034     0.007     1.000  0.118 -0.468   0.064
# LBXTC                       0.008     0.222     0.118  1.000  0.048   0.094
# BMXHT                      -0.012     0.233    -0.468  0.048  1.000   0.204
# BMXBMI                     -0.004     0.277     0.064  0.094  0.204   1.000
# BMXWT                      -0.007     0.295    -0.185  0.085  0.579   0.901
# BMXWAIST                   -0.004     0.446    -0.088  0.130  0.401   0.877
# BMXARMC                    -0.012     0.276    -0.092  0.115  0.443   0.880
# PAD680                      0.013     0.054     0.013  0.016  0.028   0.042
# SLD012                     -0.001    -0.030     0.034 -0.043 -0.066  -0.072
# DRKCAL                     -0.014    -0.011    -0.274 -0.007  0.243  -0.025
# DRPROT                     -0.006     0.009    -0.269  0.004  0.260   0.006
# DRSUGR                     -0.010    -0.014    -0.151 -0.037  0.089  -0.031
# DRFIBE                     -0.006     0.071    -0.133  0.018  0.150  -0.089
# DRTFAT                     -0.019     0.028    -0.212  0.007  0.230   0.022
# DRTALCO                     0.014     0.123    -0.117  0.099  0.153   0.015
# DRCARB                     -0.013    -0.069    -0.230 -0.044  0.152  -0.071
# DRWATER                    -0.010    -0.057    -0.027  0.064  0.138   0.081
# smoker                      0.012     0.352    -0.096  0.084  0.165   0.129
# diabetes                    0.003     0.276    -0.025 -0.106  0.044   0.213
# PAD680_log                  0.016    -0.006    -0.007 -0.008  0.067   0.080
# DRTALCO_log                 0.014     0.185    -0.106  0.137  0.181   0.013
# ethnicity_OtherHispanic       0.006  -0.062    -0.004      -0.102
# ethnicity_OtherRace          -0.006   0.048     0.023       0.002
# chol_high                     0.039   0.062    -0.015      -0.000
#
#                             DRTALCO_log  DRWATER_log  DRSUGR_log  DRFIBE_log  \
# SEQN                              0.014       -0.012      -0.007      -0.007
# RIDAGEYR                          0.185       -0.055      -0.024       0.059
# RIAGENDR                         -0.106        0.013      -0.135      -0.127
# LBXTC                             0.137        0.039      -0.040       0.020
# BMXHT                             0.181        0.053       0.056       0.130
# BMXBMI                            0.013        0.028      -0.049      -0.096
# BMXWT                             0.085        0.043      -0.010      -0.020
# BMXWAIST                          0.082       -0.000      -0.028      -0.054
# BMXARMC                           0.063        0.059      -0.038      -0.049
# PAD680                            0.018       -0.001       0.007      -0.009
# SLD012                           -0.014       -0.023      -0.003       0.002
# DRKCAL                            0.214       -0.007       0.616       0.592
# DRPROT                            0.135        0.085       0.317       0.508
# DRSUGR                           -0.009       -0.153       0.869       0.321
# DRFIBE                            0.069        0.120       0.350       0.916
# DRTFAT                            0.126        0.018       0.420       0.483
# DRTALCO                           0.817       -0.027      -0.034       0.010
# DRCARB                            0.041       -0.059       0.763       0.589
# DRWATER                           0.046        0.593      -0.102       0.100
# smoker                            0.126       -0.066       0.005      -0.057
# diabetes                         -0.057       -0.036      -0.062      -0.040
# PAD680_log                        0.052       -0.009       0.005       0.016
# DRTALCO_log                       1.000       -0.011      -0.044       0.047
# DRWATER_log                      -0.011        1.000      -0.098       0.153
# DRSUGR_log                       -0.044       -0.098       1.000       0.416
# DRFIBE_log                        0.047        0.153       0.416       1.000
# DRCARB_log                        0.022       -0.017       0.837       0.645
# DRPROT_log                        0.121        0.121       0.369       0.566
# DRTFAT_log                        0.103        0.057       0.468       0.522
# DRKCAL_log                        0.185        0.039       0.667       0.630
# BMXBMI_log                        0.033        0.031      -0.054      -0.089
# ethnicity_MexicanAmerican        -0.056        0.042       0.007       0.045
# ethnicity_NonHispanicAsian       -0.064        0.041      -0.035       0.062
# ethnicity_NonHispanicBlack       -0.033       -0.023      -0.011      -0.111
# ethnicity_NonHispanicWhite        0.133       -0.041       0.053       0.063
# ethnicity_OtherHispanic          -0.050        0.025      -0.065      -0.047
# ethnicity_OtherRace              -0.037       -0.003       0.015      -0.028
# chol_high                         0.066        0.026      -0.036      -0.005
#
#                             DRCARB_log  DRPROT_log  DRTFAT_log  DRKCAL_log  \
# SEQN                            -0.013      -0.010      -0.019      -0.013
# RIDAGEYR                        -0.077       0.009       0.016      -0.014
# RIAGENDR                        -0.213      -0.250      -0.188      -0.246
# LBXTC                           -0.042       0.006       0.008      -0.003
# BMXHT                            0.122       0.233       0.199       0.206
# BMXBMI                          -0.080       0.002       0.007      -0.032
# BMXWT                           -0.003       0.109       0.099       0.071
# BMXWAIST                        -0.046       0.040       0.048       0.016
# BMXARMC                         -0.043       0.079       0.061       0.028
# PAD680                           0.002      -0.007       0.001       0.001
# SLD012                          -0.003      -0.006       0.004      -0.002
# DRKCAL                           0.802       0.748       0.817       0.895
# DRPROT                           0.507       0.917       0.678       0.713
# DRSUGR                           0.744       0.317       0.402       0.588
# DRFIBE                           0.567       0.497       0.439       0.543
# DRTFAT                           0.579       0.700       0.904       0.799
# DRTALCO                          0.032       0.104       0.075       0.189
# DRCARB                           0.908       0.532       0.581       0.783
# DRWATER                         -0.023       0.122       0.048       0.040
# smoker                          -0.012       0.013       0.035       0.030
# diabetes                        -0.061      -0.016      -0.011      -0.042
# PAD680_log                       0.028       0.042       0.076       0.054
# DRTALCO_log                      0.022       0.121       0.103       0.185
# DRWATER_log                     -0.017       0.121       0.057       0.039
# DRSUGR_log                       0.837       0.369       0.468       0.667
# DRFIBE_log                       0.645       0.566       0.522       0.630
# DRCARB_log                       1.000       0.574       0.639       0.869
# DRPROT_log                       0.574       1.000       0.772       0.810
# DRTFAT_log                       0.639       0.772       1.000       0.887
# DRKCAL_log                       0.869       0.810       0.887       1.000
# BMXBMI_log                      -0.085       0.008       0.010      -0.031
# ethnicity_MexicanAmerican        0.015       0.004      -0.028      -0.010
# ethnicity_NonHispanicAsian       0.029       0.018      -0.020       0.002
# ethnicity_NonHispanicBlack      -0.039      -0.077      -0.055      -0.060
# ethnicity_NonHispanicWhite       0.037       0.075       0.130       0.101
# ethnicity_OtherHispanic         -0.056      -0.044      -0.121      -0.089
# ethnicity_OtherRace              0.005      -0.014       0.016       0.001
# chol_high                       -0.032      -0.006      -0.004      -0.012
#
#                             BMXBMI_log  ethnicity_MexicanAmerican  \
# SEQN                            -0.006                     -0.005
# RIDAGEYR                         0.333                     -0.146
# RIAGENDR                         0.052                     -0.010
# LBXTC                            0.120                     -0.048
# BMXHT                            0.260                     -0.113
# BMXBMI                           0.983                     -0.002
# BMXWT                            0.902                     -0.052
# BMXWAIST                         0.900                     -0.038
# BMXARMC                          0.903                     -0.024
# PAD680                           0.043                     -0.032
# SLD012                          -0.075                      0.009
# DRKCAL                          -0.022                     -0.011
# DRPROT                           0.014                      0.003
# DRSUGR                          -0.034                     -0.001
# DRFIBE                          -0.081                      0.042
# DRTFAT                           0.027                     -0.027
# DRTALCO                          0.026                     -0.044
# DRCARB                          -0.074                      0.012
# DRWATER                          0.087                      0.026
# smoker                           0.153                     -0.095
# diabetes                         0.215                     -0.002
# PAD680_log                       0.071                     -0.083
# DRTALCO_log                      0.033                     -0.056
# DRWATER_log                      0.031                      0.042
# DRSUGR_log                      -0.054                      0.007
# DRFIBE_log                      -0.089                      0.045
# DRCARB_log                      -0.085                      0.015
# DRPROT_log                       0.008                      0.004
# DRTFAT_log                       0.010                     -0.028
# DRKCAL_log                      -0.031                     -0.010
# BMXBMI_log                       1.000                     -0.001
# ethnicity_MexicanAmerican       -0.001                      1.000
# ethnicity_NonHispanicAsian      -0.137                     -0.073
# ethnicity_NonHispanicBlack       0.059                     -0.112
# ethnicity_NonHispanicWhite       0.045                     -0.340
# ethnicity_OtherHispanic         -0.025                     -0.109
# ethnicity_OtherRace             -0.010                     -0.082
# chol_high                        0.049                     -0.033
#
#                             ethnicity_NonHispanicAsian  \
# SEQN                                            -0.002
# RIDAGEYR                                        -0.033
# RIAGENDR                                         0.003
# LBXTC                                            0.036
# BMXHT                                           -0.082
# BMXBMI                                          -0.135
# BMXWT                                           -0.149
# BMXWAIST                                        -0.136
# BMXARMC                                         -0.128
# PAD680                                          -0.017
# SLD012                                          -0.022
# DRKCAL                                          -0.013
# DRPROT                                           0.002
# DRSUGR                                          -0.052
# DRFIBE                                           0.063
# DRTFAT                                          -0.036
# DRTALCO                                         -0.054
# DRCARB                                           0.015
# DRWATER                                          0.005
# smoker                                          -0.077
# diabetes                                        -0.016
# PAD680_log                                      -0.010
# DRTALCO_log                                     -0.064
# DRWATER_log                                      0.041
# DRSUGR_log                                      -0.035
# DRFIBE_log                                       0.062
# DRCARB_log                                       0.029
# DRPROT_log                                       0.018
# DRTFAT_log                                      -0.020
# DRKCAL_log                                       0.002
# BMXBMI_log                                      -0.137
# ethnicity_MexicanAmerican                       -0.073
# ethnicity_NonHispanicAsian                       1.000
# ethnicity_NonHispanicBlack                      -0.089
# ethnicity_NonHispanicWhite                      -0.272
# ethnicity_OtherHispanic                         -0.087
# ethnicity_OtherRace                             -0.065
# chol_high                                        0.013
#
#                             ethnicity_NonHispanicBlack  \
# SEQN                                            -0.020
# RIDAGEYR                                        -0.059
# RIAGENDR                                         0.002
# LBXTC                                           -0.076
# BMXHT                                            0.015
# BMXBMI                                           0.067
# BMXWT                                            0.062
# BMXWAIST                                         0.001
# BMXARMC                                          0.081
# PAD680                                           0.009
# SLD012                                          -0.028
# DRKCAL                                          -0.040
# DRPROT                                          -0.059
# DRSUGR                                           0.000
# DRFIBE                                          -0.094
# DRTFAT                                          -0.039
# DRTALCO                                         -0.009
# DRCARB                                          -0.026
# DRWATER                                         -0.042
# smoker                                          -0.018
# diabetes                                         0.038
# PAD680_log                                      -0.015
# DRTALCO_log                                     -0.033
# DRWATER_log                                     -0.023
# DRSUGR_log                                      -0.011
# DRFIBE_log                                      -0.111
# DRCARB_log                                      -0.039
# DRPROT_log                                      -0.077
# DRTFAT_log                                      -0.055
# DRKCAL_log                                      -0.060
# BMXBMI_log                                       0.059
# ethnicity_MexicanAmerican                       -0.112
# ethnicity_NonHispanicAsian                      -0.089
# ethnicity_NonHispanicBlack                       1.000
# ethnicity_NonHispanicWhite                      -0.415
# ethnicity_OtherHispanic                         -0.133
# ethnicity_OtherRace                             -0.100
# chol_high                                       -0.044
#
#                             ethnicity_NonHispanicWhite  \
# SEQN                                             0.028
# RIDAGEYR                                         0.225
# RIAGENDR                                         0.012
# LBXTC                                            0.079
# BMXHT                                            0.161
# BMXBMI                                           0.040
# BMXWT                                            0.101
# BMXWAIST                                         0.129
# BMXARMC                                          0.044
# PAD680                                           0.025
# SLD012                                           0.040
# DRKCAL                                           0.086
# DRPROT                                           0.067
# DRSUGR                                           0.052
# DRFIBE                                           0.054
# DRTFAT                                           0.114
# DRTALCO                                          0.088
# DRCARB                                           0.032
# DRWATER                                          0.010
# smoker                                           0.116
# diabetes                                        -0.026
# PAD680_log                                       0.126
# DRTALCO_log                                      0.133
# DRWATER_log                                     -0.041
# DRSUGR_log                                       0.053
# DRFIBE_log                                       0.063
# DRCARB_log                                       0.037
# DRPROT_log                                       0.075
# DRTFAT_log                                       0.130
# DRKCAL_log                                       0.101
# BMXBMI_log                                       0.045
# ethnicity_MexicanAmerican                       -0.340
# ethnicity_NonHispanicAsian                      -0.272
# ethnicity_NonHispanicBlack                      -0.415
# ethnicity_NonHispanicWhite                       1.000
# ethnicity_OtherHispanic                         -0.405
# ethnicity_OtherRace                             -0.303
# chol_high                                        0.046
#
#                             ethnicity_OtherHispanic  ethnicity_OtherRace  \
# SEQN                                         -0.010               -0.009
# RIDAGEYR                                     -0.102               -0.049
# RIAGENDR                                      0.012               -0.034
# LBXTC                                        -0.032                0.002
# BMXHT                                        -0.115                0.008
# BMXBMI                                       -0.028               -0.004
# BMXWT                                        -0.073                0.005
# BMXWAIST                                     -0.065               -0.008
# BMXARMC                                      -0.037               -0.000
# PAD680                                       -0.006               -0.001
# SLD012                                       -0.013               -0.015
# DRKCAL                                       -0.082                0.010
# DRPROT                                       -0.039               -0.012
# DRSUGR                                       -0.062                0.023
# DRFIBE                                       -0.046               -0.030
# DRTFAT                                       -0.105                0.021
# DRTALCO                                      -0.037               -0.018
# DRCARB                                       -0.051                0.009
# DRWATER                                       0.006               -0.006
# smoker                                       -0.062                0.048
# diabetes                                     -0.004                0.023
# PAD680_log                                   -0.102                0.002
# DRTALCO_log                                  -0.050               -0.037
# DRWATER_log                                   0.025               -0.003
# DRSUGR_log                                   -0.065                0.015
# DRFIBE_log                                   -0.047               -0.028
# DRCARB_log                                   -0.056                0.005
# DRPROT_log                                   -0.044               -0.014
# DRTFAT_log                                   -0.121                0.016
# DRKCAL_log                                   -0.089                0.001
# BMXBMI_log                                   -0.025               -0.010
# ethnicity_MexicanAmerican                    -0.109               -0.082
# ethnicity_NonHispanicAsian                   -0.087               -0.065
# ethnicity_NonHispanicBlack                   -0.133               -0.100
# ethnicity_NonHispanicWhite                   -0.405               -0.303
# ethnicity_OtherHispanic                       1.000               -0.097
# ethnicity_OtherRace                          -0.097                1.000
# chol_high                                    -0.021                0.017
#
#                             chol_high
# SEQN                            0.028
# RIDAGEYR                        0.133
# RIAGENDR                        0.059
# LBXTC                           0.633
# BMXHT                           0.018
# BMXBMI                          0.038
# BMXWT                           0.035
# BMXWAIST                        0.067
# BMXARMC                         0.043
# PAD680                         -0.002
# SLD012                         -0.007
# DRKCAL                         -0.016
# DRPROT                         -0.004
# DRSUGR                         -0.039
# DRFIBE                         -0.005
# DRTFAT                         -0.005
# DRTALCO                         0.046
# DRCARB                         -0.036
# DRWATER                         0.039
# smoker                          0.062
# diabetes                       -0.015
# PAD680_log                     -0.000
# DRTALCO_log                     0.066
# DRWATER_log                     0.026
# DRSUGR_log                     -0.036
# DRFIBE_log                     -0.005
# DRCARB_log                     -0.032
# DRPROT_log                     -0.006
# DRTFAT_log                     -0.004
# DRKCAL_log                     -0.012
# BMXBMI_log                      0.049
# ethnicity_MexicanAmerican      -0.033
# ethnicity_NonHispanicAsian      0.013
# ethnicity_NonHispanicBlack     -0.044
# ethnicity_NonHispanicWhite      0.046
# ethnicity_OtherHispanic        -0.021
# ethnicity_OtherRace             0.017
# chol_high                       1.000
# Corrélations avec 'chol_high' :
# chol_high                     1.000
# LBXTC                         0.633
# RIDAGEYR                      0.133
# BMXWAIST                      0.067
# DRTALCO_log                   0.066
# smoker                        0.062
# RIAGENDR                      0.059
# BMXBMI_log                    0.049
# DRTALCO                       0.046
# ethnicity_NonHispanicWhite    0.046
# BMXARMC                       0.043
# DRWATER                       0.039
# BMXBMI                        0.038
# BMXWT                         0.035
# SEQN                          0.028
# DRWATER_log                   0.026
# BMXHT                         0.018
# ethnicity_OtherRace           0.017
# ethnicity_NonHispanicAsian    0.013
# PAD680_log                   -0.000
# PAD680                       -0.002
# DRPROT                       -0.004
# DRTFAT_log                   -0.004
# DRFIBE_log                   -0.005
# DRFIBE                       -0.005
# DRTFAT                       -0.005
# DRPROT_log                   -0.006
# SLD012                       -0.007
# DRKCAL_log                   -0.012
# diabetes                     -0.015
# DRKCAL                       -0.016
# ethnicity_OtherHispanic      -0.021
# DRCARB_log                   -0.032
# ethnicity_MexicanAmerican    -0.033
# DRSUGR_log                   -0.036
# DRCARB                       -0.036
# DRSUGR                       -0.039
# ethnicity_NonHispanicBlack   -0.044
# Name: chol_high, dtype: float64

# %%
# Cellule 6 — Split stratifié train / val / test

X_train_full, X_test, y_train_full, y_test = train_test_split(
    X_full, y, test_size=0.20, stratify=y, random_state=RANDOM_STATE
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_full, y_train_full, test_size=0.25, stratify=y_train_full, random_state=RANDOM_STATE
)

print("=== Répartition ===")
print(f"Train : {len(X_train)} | Val : {len(X_val)} | Test : {len(X_test)}")
print("Taux pos — Train/Val/Test :", round(y_train.mean(),3), round(y_val.mean(),3), round(y_test.mean(),3))
# Out:
# === Répartition ===
# Train : 4133 | Val : 1378 | Test : 1378
# Taux pos — Train/Val/Test : 0.09 0.09 0.089

# %%
# Cellule 7 — Standardisation sélective

binary_cols = ["RIAGENDR", "smoker"]
if USE_ETHNICITY:
    binary_cols += [
        "ethnicity_MexicanAmerican", "ethnicity_OtherHispanic",
        "ethnicity_NonHispanicWhite", "ethnicity_NonHispanicBlack",
        "ethnicity_NonHispanicAsian", "ethnicity_OtherRace"
    ]
binary_cols = [c for c in binary_cols if c in X_train.columns]

num_cols = [c for c in X_train.columns if c not in binary_cols]
print(f"Colonnes standardisées ({len(num_cols)}) : {num_cols}")

scaler = StandardScaler()
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_val[num_cols]   = scaler.transform(X_val[num_cols])
X_test[num_cols]  = scaler.transform(X_test[num_cols])

joblib.dump(scaler, "scaler_diab.pkl")
print("Scaler sauvegardé : scaler_diab.pkl")
# Out:
# Colonnes standardisées (13) : ['RIDAGEYR', 'BMXBMI_log', 'BMXWAIST', 'PAD680_log', 'SLD012', 'DRKCAL_log', 'DRPROT_log', 'DRSUGR_log', 'DRFIBE_log', 'DRTFAT_log', 'DRCARB_log', 'DRTALCO_log', 'DRWATER_log']
# Scaler sauvegardé : scaler_diab.pkl

# %%
# Cellule 8 — Hyperparameter Search (RandomizedSearchCV)

from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from scipy.stats import randint, uniform

# Espace de recherche (sobre et efficace pour LGBM)
param_distributions = {
    "num_leaves": randint(15, 80),
    "max_depth": randint(3, 12),                # -1 laissé au refit final si besoin
    "min_child_samples": randint(10, 120),
    "min_split_gain": uniform(0.0, 0.5),
    "subsample": uniform(0.6, 0.4),             # 0.6 → 1.0
    "colsample_bytree": uniform(0.6, 0.4),
    "reg_alpha": uniform(0.0, 0.3),
    "reg_lambda": uniform(0.0, 0.6),
    "learning_rate": uniform(0.01, 0.09),       # 0.01 → 0.10
    "n_estimators": randint(200, 1200)          # pas d'early stopping pendant la CV
}

base_estimator = lgb.LGBMClassifier(
    objective="binary",
    class_weight="balanced",
    random_state=RANDOM_STATE,
    n_jobs=-1
)

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

rs = RandomizedSearchCV(
    estimator=base_estimator,
    param_distributions=param_distributions,
    n_iter=40,               # augmente si tu veux pousser plus
    scoring="roc_auc",
    cv=cv,
    verbose=1,
    n_jobs=-1,
    refit=True,
    random_state=RANDOM_STATE
)

rs.fit(X_train, y_train)     # on réserve X_val pour le early stopping du refit final

print("\n=== RandomizedSearchCV terminé ===")
print("Best CV AUC :", rs.best_score_)
print("Best params :")
for k, v in rs.best_params_.items():
    print(f"  {k}: {v}")

best_params = rs.best_params_.copy()
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [LightGBM] [Info] Number of positive: 370, number of negative: 3763
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001190 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2693
# [LightGBM] [Info] Number of data points in the train set: 4133, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#
# === RandomizedSearchCV terminé ===
# Best CV AUC : 0.720149276384972
# Best params :
#   colsample_bytree: 0.8363333042276043
#   learning_rate: 0.012745022494514448
#   max_depth: 6
#   min_child_samples: 51
#   min_split_gain: 0.4113002803298291
#   n_estimators: 253
#   num_leaves: 74
#   reg_alpha: 0.09799537253881226
#   reg_lambda: 0.4967214022725532
#   subsample: 0.7086171663278967

# %%
# Cellule 9 — Refit final (train+val) avec early stopping + sauvegardes

from sklearn.model_selection import train_test_split
import json
from pathlib import Path

# On combine train et val (déjà standardisés avec le même scaler)
X_trval = pd.concat([X_train, X_val], axis=0)
y_trval = pd.concat([y_train, y_val], axis=0)

# Petit split interne pour l'early stopping (10% du train+val)
X_tr, X_es, y_tr, y_es = train_test_split(
    X_trval, y_trval, test_size=0.10, stratify=y_trval, random_state=RANDOM_STATE
)

# Modèle final avec les meilleurs params + marge sur n_estimators (piloté par early stopping)
final_params = dict(best_params)
final_params.update({
    "objective": "binary",
    "class_weight": "balanced",
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "n_estimators": max(1500, int(best_params.get("n_estimators", 600) * 2))
})

lgb_tuned = lgb.LGBMClassifier(**final_params)

lgb_tuned.fit(
    X_tr, y_tr,
    eval_set=[(X_es, y_es)],
    eval_metric="auc",
    callbacks=[lgb.early_stopping(stopping_rounds=150), lgb.log_evaluation(period=100)]
)

# Sauvegardes
ART = Path("artifacts_chol_lgbm_tuned"); ART.mkdir(exist_ok=True)
joblib.dump(lgb_tuned, ART / "model_lightgbm_chol_tuned.pkl")
joblib.dump(scaler,   ART / "scaler_chol.pkl")

with open(ART / "best_params.json", "w") as f:
    json.dump(best_params, f, indent=2)

print("\nModèle final sauvegardé :", ART / "model_lightgbm_chol_tuned.pkl")
print("Params sauvegardés      :", ART / "best_params.json")
# Out:
# [LightGBM] [Info] Number of positive: 445, number of negative: 4514
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000991 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2699
# [LightGBM] [Info] Number of data points in the train set: 4959, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=-0.000000
# [LightGBM] [Info] Start training from score -0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Training until validation scores don't improve for 150 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's auc: 0.777742	valid_0's binary_logloss: 0.559604
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's auc: 0.77194	valid_0's binary_logloss: 0.520072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Early stopping, best iteration is:
# [64]	valid_0's auc: 0.782042	valid_0's binary_logloss: 0.5866
#
# Modèle final sauvegardé : artifacts_chol_lgbm_tuned\model_lightgbm_chol_tuned.pkl
# Params sauvegardés      : artifacts_chol_lgbm_tuned\best_params.json

# %%
# Cellule 10 — Évaluation sur le jeu de test (seuil 0.5) avec lgb_tuned

y_test_proba = lgb_tuned.predict_proba(X_test)[:, 1]
y_test_pred  = (y_test_proba >= 0.5).astype(int)

print("=== RAPPORT DE CLASSIFICATION (TEST, seuil 0.5) ===")
print(classification_report(y_test, y_test_pred, digits=3))
print(f"ROC AUC (test) : {roc_auc_score(y_test, y_test_proba):.4f}")

RocCurveDisplay.from_estimator(lgb_tuned, X_test, y_test)
plt.title("ROC — Test (modèle tuné)")
plt.grid(alpha=0.3); plt.show()

ConfusionMatrixDisplay.from_estimator(lgb_tuned, X_test, y_test, cmap="Blues")
plt.title("Matrice de confusion — Test (0.5) — Tuné")
plt.grid(False); plt.show()
# Out:
# === RAPPORT DE CLASSIFICATION (TEST, seuil 0.5) ===
#               precision    recall  f1-score   support
#
#            0      0.959     0.603     0.741      1255
#            1      0.154     0.740     0.256       123
#
#     accuracy                          0.615      1378
#    macro avg      0.557     0.672     0.498      1378
# weighted avg      0.888     0.615     0.697      1378
#
# ROC AUC (test) : 0.7209

# %%
# Cellule 11 — Seuil optimal (max F1) pour lgb_tuned

from sklearn.metrics import precision_recall_curve

y_scores = y_test_proba  # alias

precisions, recalls, thresholds = precision_recall_curve(y_test, y_scores)
f1_scores = 2 * (precisions * recalls) / (precisions + recalls + 1e-8)

best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

print(f"=== Seuil optimal ===")
print(f"Seuil : {best_threshold:.3f}")
print(f"F1 max : {best_f1:.3f}")
print(f"Précision : {precisions[best_idx]:.3f}")
print(f"Rappel    : {recalls[best_idx]:.3f}")

plt.figure(figsize=(7,5))
plt.plot(thresholds, f1_scores[:-1], label="F1")
plt.axvline(best_threshold, color="red", linestyle="--", label=f"Best={best_threshold:.2f}")
plt.title("Évolution du F1-score selon le seuil — Test (tuné)")
plt.xlabel("Seuil"); plt.ylabel("F1-score")
plt.legend(); plt.grid(True, linestyle="--", alpha=0.6); plt.tight_layout(); plt.show()

y_pred_opt = (y_scores >= best_threshold).astype(int)
print(f"\n=== RAPPORT (Seuil {best_threshold:.2f}) ===")
print(classification_report(y_test, y_pred_opt, digits=3))

ConfusionMatrixDisplay.from_predictions(y_test, y_pred_opt, cmap="Blues")
plt.title(f"Matrice de confusion — Seuil {best_threshold:.2f} — Tuné")
plt.grid(False); plt.show()
# Out:
# === Seuil optimal ===
# Seuil : 0.521
# F1 max : 0.264
# Précision : 0.165
# Rappel    : 0.659
# === RAPPORT (Seuil 0.52) ===
#               precision    recall  f1-score   support
#
#            0      0.953     0.674     0.790      1255
#            1      0.165     0.659     0.264       123
#
#     accuracy                          0.673      1378
#    macro avg      0.559     0.666     0.527      1378
# weighted avg      0.882     0.673     0.743      1378

# %%
# Cellule 12 : Distribution des faux positifs dans les 3 zones de cholestérol (seuil 0.5) 

# 1) Prédictions au seuil 0.5
y_scores = lgb_tuned.predict_proba(X_test)[:, 1]
y_pred_05 = (y_scores >= 0.5).astype(int)

# 2) DataFrame test + cholestérol
df_test_full = X_test.copy()
df_test_full["y_true"] = y_test.values
df_test_full["y_pred"] = y_pred_05
df_test_full["y_proba"] = y_scores
df_test_full["LBXTC"] = df.loc[X_test.index, "LBXTC"]

# 3) Faux positifs (prédits malades alors qu'ils sont sains)
fp_df = df_test_full[(df_test_full["y_true"] == 0) & (df_test_full["y_pred"] == 1)]

# 4) Découpage en 3 zones
zone_normal = fp_df[fp_df["LBXTC"] < 200]
zone_grey   = fp_df[(fp_df["LBXTC"] >= 200) & (fp_df["LBXTC"] <= 240)]
zone_high   = fp_df[fp_df["LBXTC"] > 240]

total_fp = len(fp_df)

# 5) Affichage des résultats
print(f"Faux positifs totaux (seuil 0.5) : {total_fp}\n")

print(f"Zone <200 mg/dL     : {len(zone_normal)}  ({len(zone_normal)/total_fp*100:.1f} %)")
print(f"Zone 200–240 mg/dL  : {len(zone_grey)}   ({len(zone_grey)/total_fp*100:.1f} %)")
print(f"Zone >240 mg/dL     : {len(zone_high)}   ({len(zone_high)/total_fp*100:.1f} %)\n")

# 6) Option : stats descriptives
display(fp_df["LBXTC"].describe().round(1))
# Out:
# Faux positifs totaux (seuil 0.5) : 498
#
# Zone <200 mg/dL     : 335  (67.3 %)
# Zone 200–240 mg/dL  : 163   (32.7 %)
# Zone >240 mg/dL     : 0   (0.0 %)
# count    498.0
# mean     182.2
# std       31.8
# min       62.0
# 25%      162.0
# 50%      184.0
# 75%      205.0
# max      240.0
# Name: LBXTC, dtype: float64
