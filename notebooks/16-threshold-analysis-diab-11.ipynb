# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import (
    classification_report, confusion_matrix,
    precision_score, recall_score
)
import joblib

# Charger modèle + scaler
model = joblib.load("artifacts_diab_no_bias/model_lightgbm_diab_no_bias.pkl")
scaler = joblib.load("artifacts_diab_no_bias/scaler_diab_no_bias.pkl")

# Charger les CSV test générés dans le notebook 15
X_test = pd.read_csv("X_test_chol.csv")
y_test = pd.read_csv("y_test_chol.csv").values.ravel()

print("OK - Modèle et jeux test chargés.")
# Out:
# OK - Modèle et jeux test chargés.

# %%
# Cellule 2 — Recalculer les colonnes NUM / BINAIRES

ethn = [
    "ethnicity_MexicanAmerican", "ethnicity_OtherHispanic",
    "ethnicity_NonHispanicWhite", "ethnicity_NonHispanicBlack",
    "ethnicity_NonHispanicAsian", "ethnicity_OtherRace"
]

binary_cols = ["RIAGENDR", "smoker"] + ethn
binary_cols = [c for c in binary_cols if c in X_test.columns]
num_cols = [c for c in X_test.columns if c not in binary_cols]

# %%
# Cellule 3 — Recréer X_test_scaled

X_test_scaled = X_test.copy()
X_test_scaled[num_cols] = scaler.transform(X_test[num_cols])

# %%
# Cellule 4 — Probabilités correctes

probas = model.predict_proba(X_test_scaled)[:, 1]
print("Probabilités générées.")
# Out:
# Probabilités générées.

# %%
def evaluate_threshold(threshold, y_true, probas):
    y_pred = (probas >= threshold).astype(int)

    print("="*60)
    print(f"SEUIL = {threshold:.3f}")
    print("="*60)

    print(classification_report(y_true, y_pred, digits=3))

    prec = precision_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred)

    print(f"Precision : {prec:.3f}")
    print(f"Recall    : {rec:.3f}")
    print("Confusion matrix :")
    print(confusion_matrix(y_true, y_pred))

    return prec, rec

# %%
thresholds = np.arange(0.05, 0.95, 0.05)

rows = []
for th in thresholds:
    prec, rec = evaluate_threshold(th, y_test, probas)
    rows.append([th, prec, rec])

df_thr = pd.DataFrame(rows, columns=["threshold", "precision", "recall"])
df_thr
# Out:
# ============================================================
# SEUIL = 0.050
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.998     0.361     0.531      1223
#            1      0.165     0.994     0.283       155
#
#     accuracy                          0.433      1378
#    macro avg      0.581     0.677     0.407      1378
# weighted avg      0.904     0.433     0.503      1378
#
# Precision : 0.165
# Recall    : 0.994
# Confusion matrix :
# [[442 781]
#  [  1 154]]
# ============================================================
# SEUIL = 0.100
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.998     0.426     0.597      1223
#            1      0.180     0.994     0.305       155
#
#     accuracy                          0.490      1378
#    macro avg      0.589     0.710     0.451      1378
# weighted avg      0.906     0.490     0.564      1378
#
# Precision : 0.180
# Recall    : 0.994
# Confusion matrix :
# [[521 702]
#  [  1 154]]
# ============================================================
# SEUIL = 0.150
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.995     0.465     0.634      1223
#            1      0.189     0.981     0.316       155
#
#     accuracy                          0.523      1378
#    macro avg      0.592     0.723     0.475      1378
# weighted avg      0.904     0.523     0.598      1378
#
# Precision : 0.189
# Recall    : 0.981
# Confusion matrix :
# [[569 654]
#  [  3 152]]
# ============================================================
# SEUIL = 0.200
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.995     0.492     0.659      1223
#            1      0.197     0.981     0.328       155
#
#     accuracy                          0.547      1378
#    macro avg      0.596     0.736     0.493      1378
# weighted avg      0.905     0.547     0.621      1378
#
# Precision : 0.197
# Recall    : 0.981
# Confusion matrix :
# [[602 621]
#  [  3 152]]
# ============================================================
# SEUIL = 0.250
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.994     0.519     0.682      1223
#            1      0.204     0.974     0.338       155
#
#     accuracy                          0.570      1378
#    macro avg      0.599     0.747     0.510      1378
# weighted avg      0.905     0.570     0.643      1378
#
# Precision : 0.204
# Recall    : 0.974
# Confusion matrix :
# [[635 588]
#  [  4 151]]
# ============================================================
# SEUIL = 0.300
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.984     0.555     0.710      1223
#            1      0.209     0.929     0.342       155
#
#     accuracy                          0.597      1378
#    macro avg      0.597     0.742     0.526      1378
# weighted avg      0.897     0.597     0.668      1378
#
# Precision : 0.209
# Recall    : 0.929
# Confusion matrix :
# [[679 544]
#  [ 11 144]]
# ============================================================
# SEUIL = 0.350
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.981     0.589     0.736      1223
#            1      0.219     0.910     0.353       155
#
#     accuracy                          0.625      1378
#    macro avg      0.600     0.749     0.544      1378
# weighted avg      0.895     0.625     0.693      1378
#
# Precision : 0.219
# Recall    : 0.910
# Confusion matrix :
# [[720 503]
#  [ 14 141]]
# ============================================================
# SEUIL = 0.400
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.977     0.621     0.759      1223
#            1      0.228     0.884     0.362       155
#
#     accuracy                          0.650      1378
#    macro avg      0.602     0.752     0.561      1378
# weighted avg      0.893     0.650     0.714      1378
#
# Precision : 0.228
# Recall    : 0.884
# Confusion matrix :
# [[759 464]
#  [ 18 137]]
# ============================================================
# SEUIL = 0.450
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.971     0.654     0.782      1223
#            1      0.236     0.845     0.370       155
#
#     accuracy                          0.676      1378
#    macro avg      0.604     0.750     0.576      1378
# weighted avg      0.888     0.676     0.735      1378
#
# Precision : 0.236
# Recall    : 0.845
# Confusion matrix :
# [[800 423]
#  [ 24 131]]
# ============================================================
# SEUIL = 0.500
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.968     0.702     0.814      1223
#            1      0.258     0.819     0.393       155
#
#     accuracy                          0.715      1378
#    macro avg      0.613     0.760     0.603      1378
# weighted avg      0.889     0.715     0.766      1378
#
# Precision : 0.258
# Recall    : 0.819
# Confusion matrix :
# [[858 365]
#  [ 28 127]]
# ============================================================
# SEUIL = 0.550
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.960     0.751     0.843      1223
#            1      0.278     0.755     0.406       155
#
#     accuracy                          0.752      1378
#    macro avg      0.619     0.753     0.625      1378
# weighted avg      0.884     0.752     0.794      1378
#
# Precision : 0.278
# Recall    : 0.755
# Confusion matrix :
# [[919 304]
#  [ 38 117]]
# ============================================================
# SEUIL = 0.600
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.946     0.805     0.870      1223
#            1      0.293     0.639     0.402       155
#
#     accuracy                          0.786      1378
#    macro avg      0.620     0.722     0.636      1378
# weighted avg      0.873     0.786     0.817      1378
#
# Precision : 0.293
# Recall    : 0.639
# Confusion matrix :
# [[984 239]
#  [ 56  99]]
# ============================================================
# SEUIL = 0.650
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.937     0.850     0.892      1223
#            1      0.317     0.548     0.402       155
#
#     accuracy                          0.816      1378
#    macro avg      0.627     0.699     0.647      1378
# weighted avg      0.867     0.816     0.836      1378
#
# Precision : 0.317
# Recall    : 0.548
# Confusion matrix :
# [[1040  183]
#  [  70   85]]
# ============================================================
# SEUIL = 0.700
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.929     0.893     0.911      1223
#            1      0.355     0.465     0.402       155
#
#     accuracy                          0.845      1378
#    macro avg      0.642     0.679     0.656      1378
# weighted avg      0.865     0.845     0.854      1378
#
# Precision : 0.355
# Recall    : 0.465
# Confusion matrix :
# [[1092  131]
#  [  83   72]]
# ============================================================
# SEUIL = 0.750
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.916     0.929     0.922      1223
#            1      0.370     0.329     0.348       155
#
#     accuracy                          0.861      1378
#    macro avg      0.643     0.629     0.635      1378
# weighted avg      0.855     0.861     0.858      1378
#
# Precision : 0.370
# Recall    : 0.329
# Confusion matrix :
# [[1136   87]
#  [ 104   51]]
# ============================================================
# SEUIL = 0.800
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.907     0.956     0.931      1223
#            1      0.393     0.226     0.287       155
#
#     accuracy                          0.874      1378
#    macro avg      0.650     0.591     0.609      1378
# weighted avg      0.849     0.874     0.858      1378
#
# Precision : 0.393
# Recall    : 0.226
# Confusion matrix :
# [[1169   54]
#  [ 120   35]]
# ============================================================
# SEUIL = 0.850
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.893     0.984     0.936      1223
#            1      0.345     0.065     0.109       155
#
#     accuracy                          0.881      1378
#    macro avg      0.619     0.524     0.522      1378
# weighted avg      0.831     0.881     0.843      1378
#
# Precision : 0.345
# Recall    : 0.065
# Confusion matrix :
# [[1204   19]
#  [ 145   10]]
# ============================================================
# SEUIL = 0.900
# ============================================================
#               precision    recall  f1-score   support
#
#            0      0.889     0.998     0.940      1223
#            1      0.500     0.019     0.037       155
#
#     accuracy                          0.888      1378
#    macro avg      0.695     0.508     0.489      1378
# weighted avg      0.845     0.888     0.839      1378
#
# Precision : 0.500
# Recall    : 0.019
# Confusion matrix :
# [[1220    3]
#  [ 152    3]]
#     threshold  precision    recall
# 0        0.05   0.164706  0.993548
# 1        0.10   0.179907  0.993548
# 2        0.15   0.188586  0.980645
# 3        0.20   0.196636  0.980645
# 4        0.25   0.204330  0.974194
# 5        0.30   0.209302  0.929032
# 6        0.35   0.218944  0.909677
# 7        0.40   0.227953  0.883871
# 8        0.45   0.236462  0.845161
# 9        0.50   0.258130  0.819355
# 10       0.55   0.277910  0.754839
# 11       0.60   0.292899  0.638710
# 12       0.65   0.317164  0.548387
# 13       0.70   0.354680  0.464516
# 14       0.75   0.369565  0.329032
# 15       0.80   0.393258  0.225806
# 16       0.85   0.344828  0.064516
# 17       0.90   0.500000  0.019355
